# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(font_scale=1.5)
sns.set(style='whitegrid')
plt.style.use("seaborn")

# %%
rs = np.random.RandomState(0)
n, p = 40, 8
d = rs.normal(0, 2, (n,p))
d += np.log(np.arange(1, p + 1)) * -5 + 10
pd.DataFrame(d).sample()
# Out:
#            0         1         2         3         4         5         6  \
# 24  9.921434  4.198077  5.553492  2.725436  3.496392  2.688211  4.596921
#
#            7
# 24  2.275848

# %%
pal = sns.cubehelix_palette(p, rot=-.5, dark=.3)
pal
# Out:
# [[0.8169009978588195, 0.8849596260223263, 0.7616710923850389],
#  [0.6983287486762216, 0.8298175878855895, 0.6677988385440397],
#  [0.5772326160415087, 0.7714422748514363, 0.5981521300377665],
#  [0.4629748539214773, 0.705712030196455, 0.5493046856781335],
#  [0.3629062505494751, 0.6301778960302135, 0.5143442519262948],
#  [0.281331005820494, 0.5443607937903802, 0.4841016935299329],
#  [0.21624286340091695, 0.4448723771080803, 0.44657182426748937],
#  [0.17051215858853222, 0.344636926092434, 0.3959064384004337]]

# %%
sns.palplot(pal)

# %%
sns.violinplot(data=d, palette=pal, inner="points")

# %%
sns.violinplot(data=d, palette=pal, inner="box")

# %% [markdown]
# #### quartile은 1사분위수 2사분위수 3사분위수를 표시해 준다.

# %%
sns.violinplot(data=d, palette=pal, inner="quartile")
